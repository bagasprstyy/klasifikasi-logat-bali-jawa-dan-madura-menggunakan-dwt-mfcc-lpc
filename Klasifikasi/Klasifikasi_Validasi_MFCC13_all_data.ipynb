# %%
# !pip install pydub
# !pip install python_speech_features
# !pip install neuralnetwork
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python_speech_features
#   Building wheel for python_speech_features (setup.py) ... done
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5870 sha256=150708d7dabe5a4919764b48231af8ade7848e3ed256736ba64cf09113ca69c6
#   Stored in directory: /root/.cache/pip/wheels/5a/9e/68/30bad9462b3926c29e315df16b562216d12bdc215f4d240294
# Successfully built python_speech_features
# Installing collected packages: python_speech_features
# Successfully installed python_speech_features-0.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting neuralnetwork
#   Downloading neuralnetwork-1.8-py3-none-any.whl (10 kB)
# Collecting python-dotenv (from neuralnetwork)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, neuralnetwork
# Successfully installed neuralnetwork-1.8 python-dotenv-1.0.0

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: fastai, imbalanced-learn, librosa, lightgbm, mlxtend, qudida, sklearn-pandas, yellowbrick

# %%
# !pip install scikit-learn==1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==1.0
#   Downloading scikit-learn-1.0.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (1.22.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (3.1.0)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (pyproject.toml) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-1.0-cp310-cp310-linux_x86_64.whl size=25849319 sha256=28f19217986ccde4ebce43dad0031072654a01da16c54fdfdcc9c0dbffc0cf5a
#   Stored in directory: /root/.cache/pip/wheels/dc/ac/81/f7dc596b727fdedc2b8f05ef115393b07478ee09a76edebdff
# Successfully built scikit-learn
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.10.1 requires scikit-learn>=1.0.2, but you have scikit-learn 1.0 which is incompatible.
# Successfully installed scikit-learn-1.0

# %% [markdown]
# IMPORT DATASET

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import matplotlib.pyplot as plt
import csv
import keras
import numpy
import random
import itertools
import tensorflow as tf
from numpy import *
from __future__ import division
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from numpy import loadtxt
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from timeit import default_timer as timer
from itertools import product
from sklearn.preprocessing import LabelEncoder

# %%
np.set_printoptions(suppress=True)

# mount gdrive with this code
from google.colab import drive
drive.mount('/content/drive')
#below where the file is in gdrive, change with your
feature_path = "/content/drive/My Drive/Program Skripsi/all_data/"
label_path = "/content/drive/My Drive/Program Skripsi/"

#load the dataset
#feature
feature = loadtxt(feature_path + 'feature_mfcc13_all_data.csv', delimiter=',')

#label
label = loadtxt(label_path + 'label_all_data.csv', delimiter=',')

X = feature
y = label

#print(X)
#print(y)

print(feature.shape)
# Out:
# Mounted at /content/drive
# (180, 26)

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion Matrix', cmap=plt.cm.Blues):
     """
     This function prints and plots the confusion matrix.
     Normalization can be applied by setting `normalize=True`.
     """
     if normalize:
       cm=cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
       print("Normalized Confusion Matrix")
     else:
       print('Confusion Matrix, without normalization')

     print(cm)
     plt.figure(figsize=(6,6), dpi=100)
     plt.imshow(cm, interpolation='nearest', cmap=cmap)
     plt.title(title)
     tick_marks = np.arange(len(classes))
     plt.xticks(tick_marks, classes, rotation=90)
     plt.yticks(tick_marks, classes)

     fmt = '.2f' if normalize else 'd'
     thresh = cm.max()/2
     for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
       plt.text(j, i, format(cm[i, j], fmt),
                horizontalalignment="center",
                color="white" if cm[i,j] > thresh else "black")

     plt.tight_layout()
     plt.ylabel('True Label')
     plt.xlabel('Predicted Label')

def tampil_cm_train(X_train, y_train, model):
    #confusion matrix
    class_names = ['Bali','Jawa','Madura']
    m = 1
    n = class_names
    m1 = str(m)
    m2 = str(n)
    model.save("feature_mfcc13_all_data_"+m2+'_'+m1+".hdf5") #sesuaikan dengan dataset yang digunakan
    print(model)

    pred_labels = model.predict(X_train)
    cm = confusion_matrix(y_train.argmax(axis=1), pred_labels.argmax(axis=1))
    cm

    class_names = ['Bali','Jawa','Madura']
    plot_confusion_matrix(cm, classes=class_names, normalize=False)
    plt.show()
    cm_stat(cm)
    return model.save("feature_mfcc13_all_data_"+m2+'_'+m1+".hdf5")

def tampil_cm_test(X_test, y_test, model):
    class_names = ['Bali','Jawa','Madura']
    m = 1
    n = class_names
    m1 = str(m)
    m2 = str(n)
    model.save("feature_mfcc13_all_data_"+m2+'_'+m1+".hdf5")
    print(model)

    pred_labels = model.predict(X_test) #test input
    cm = confusion_matrix(y_test.argmax(axis=1), pred_labels.argmax(axis=1))
    cm

    class_names = ['Bali','Jawa','Madura']
    plot_confusion_matrix(cm, classes=class_names, normalize=False)
    plt.show()
    cm_stat(cm)
    return model.save("feature_mfcc13_all_data_"+m2+'_'+m1+".hdf5")

def cm_stat(cm):
    FP = cm.sum(axis=0) - np.diag(cm)
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)
    print("komponen")
    print("FP :",FP,"   FN :",FN,"   TP :",TP,"   TN :",TN)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    print("TPR")
    print(TPR*100)
    # Specificity or true negative rate
    TNR = TN/(TN+FP)
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    print("Precision")
    print(PPV*100)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)
    print("FDR")
    print(FDR*100)

    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)
    print("Akurasi")
    print(ACC*100)

    return PPV,ACC,TPR,FDR

def predict(signal_predict):
    signals=np.stack([extract_feature_signal(signal_predict)])
    #do the prediction
    prediction = model.predict(signals, batch_size=1)
    print("Prediction: %s, confidence: %.2f" % (np.argmax(prediction), np.max(prediction)))

# %%
def labels_encoder(y):
    y_new = LabelEncoder().fit_transform([''.join(str(l)) for l in y])
    return y_new

def labels_decoder(y):
    lb = preprocessing.LabelBinarizer()
    lb.fit(y)
    lb.classes_
    labels_1_nn = lb.transform(y)
    return labels_1_nn

# %%
#TRAINING&TESTING
def trainingdata (X, y):
    seed = np.random.seed(25)
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed) #menyatakan fungsi KFoldnya
    kf.get_n_splits(X) #Memisah testing-training sesuai spesifikasi KFoldnya #feature itu nama datanya nanti diganti aja
    print(kf) #untuk melihat spesifikasi KFoldnya
    cvscores = []
    m = 1
    n = class_names
    for train, test in kf.split(X, y):
        y_new = labels_decoder(y)

        #define the keras model
        model = Sequential()
        model.add(Dense(19, input_dim=26, activation='relu'))
        model.add(Dense(3, activation='softmax'))

        #compile the keras model
        model.compile(loss='categorical_crossentropy',
                      optimizer='adam',
                      metrics=['accuracy'])
        print(model.summary())

        X_train, X_test, y_train, y_test = X[train], X[test], y_new[train], y_new[test]

        #fit the keras model on the dataset
        model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2) #verbose digunakan agar tidak ada error saat training
        loss, acc = model.evaluate(X_test, y_test, batch_size=1)
        print("Loss: %.2f, accuracy: %.2f" %(loss, acc))

        m1 = str(m)
        m2 = str(n)

        model.save("feature_mfcc13_all_data_"+m2+'_'+m1+".hdf5") #tergantung jumlah koefisiennya
        print(model)

        tampil_cm_train(X_train, y_train, model)
        tampil_cm_test(X_test, y_test, model)

        m = m+1

        #evaluate the keras model
        scores = model.evaluate(X, y_new)
        print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
        cvscores.append(scores[1]*100)

    # print out average and standard deviation of model performance to provide a robust estimate of the model's accuracy.
    maks = max(cvscores)
    print("akurasi tertinggi = ", max(cvscores))
    print("\nAkurasi rata rata is %.2f%%" % numpy.mean(cvscores))
    return maks, numpy.mean(cvscores)

# %%
def run_all (X, y):
    X, y = feature, label
    max_acc, mean_acc = trainingdata(X, y)
    return max_acc, mean_acc

# %%
scores_logat = []
scores_logat_testing = []

class_names = ['Bali','Jawa','Madura']
logat_max_acc, logat_mean_acc = run_all (26,class_names)
scores_logat.append(logat_mean_acc)
# Out:
# StratifiedKFold(n_splits=10, random_state=None, shuffle=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 19)                513
#
#  dense_1 (Dense)             (None, 3)                 60
#
# =================================================================
# Total params: 573
# Trainable params: 573
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 4.9547 - accuracy: 0.4815 - 1s/epoch - 8ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.3631 - accuracy: 0.7284 - 307ms/epoch - 2ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.7329 - accuracy: 0.7593 - 284ms/epoch - 2ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.4927 - accuracy: 0.8395 - 300ms/epoch - 2ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.3485 - accuracy: 0.8827 - 302ms/epoch - 2ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.2605 - accuracy: 0.9074 - 282ms/epoch - 2ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.1646 - accuracy: 0.9506 - 297ms/epoch - 2ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.1088 - accuracy: 0.9691 - 293ms/epoch - 2ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.1323 - accuracy: 0.9444 - 293ms/epoch - 2ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0970 - accuracy: 0.9444 - 314ms/epoch - 2ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0793 - accuracy: 0.9630 - 314ms/epoch - 2ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0579 - accuracy: 0.9815 - 233ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0520 - accuracy: 0.9753 - 185ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0459 - accuracy: 0.9815 - 196ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0373 - accuracy: 0.9877 - 194ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0249 - accuracy: 1.0000 - 196ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0295 - accuracy: 0.9877 - 211ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0210 - accuracy: 0.9938 - 204ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0226 - accuracy: 0.9938 - 209ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0179 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0199 - accuracy: 0.9938 - 204ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0128 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0124 - accuracy: 1.0000 - 192ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0091 - accuracy: 1.0000 - 197ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0067 - accuracy: 1.0000 - 196ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0069 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0071 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0101 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0052 - accuracy: 1.0000 - 248ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0041 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0043 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0043 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0034 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0034 - accuracy: 1.0000 - 198ms/epoch - 1ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 0.0030 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0021 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 0.0017 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 9.8647e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 9.4607e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 8.8790e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 7.3170e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 6.6291e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 6.2103e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 5.5609e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 5.6582e-04 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 4.3708e-04 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 4.4005e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 4.0764e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 3.5430e-04 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 3.2394e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 2.8552e-04 - accuracy: 1.0000 - 263ms/epoch - 2ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 2.6097e-04 - accuracy: 1.0000 - 275ms/epoch - 2ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 2.2809e-04 - accuracy: 1.0000 - 287ms/epoch - 2ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 2.2728e-04 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 1.8052e-04 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 1.7519e-04 - accuracy: 1.0000 - 287ms/epoch - 2ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 1.5627e-04 - accuracy: 1.0000 - 309ms/epoch - 2ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 1.4161e-04 - accuracy: 1.0000 - 288ms/epoch - 2ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 1.3987e-04 - accuracy: 1.0000 - 260ms/epoch - 2ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 1.2865e-04 - accuracy: 1.0000 - 305ms/epoch - 2ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 1.0810e-04 - accuracy: 1.0000 - 279ms/epoch - 2ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 9.6935e-05 - accuracy: 1.0000 - 285ms/epoch - 2ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 9.8514e-05 - accuracy: 1.0000 - 312ms/epoch - 2ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 8.9343e-05 - accuracy: 1.0000 - 288ms/epoch - 2ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 8.3258e-05 - accuracy: 1.0000 - 305ms/epoch - 2ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 7.3349e-05 - accuracy: 1.0000 - 305ms/epoch - 2ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 6.2651e-05 - accuracy: 1.0000 - 258ms/epoch - 2ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 6.1985e-05 - accuracy: 1.0000 - 196ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 5.4878e-05 - accuracy: 1.0000 - 194ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 5.2636e-05 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 4.5275e-05 - accuracy: 1.0000 - 200ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 4.4455e-05 - accuracy: 1.0000 - 194ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 3.8734e-05 - accuracy: 1.0000 - 190ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 3.7654e-05 - accuracy: 1.0000 - 199ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 3.5157e-05 - accuracy: 1.0000 - 184ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 2.9126e-05 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 2.7451e-05 - accuracy: 1.0000 - 200ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 2.5440e-05 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 2.2386e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 1.9700e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 1.9383e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 1.7406e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 1.4608e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 1.5374e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 1.3476e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 1.2244e-05 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 1.1330e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 1.0844e-05 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 1.0419e-05 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 7.8219e-06 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 8.5790e-06 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 7.3238e-06 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.9444
# Loss: 0.10, accuracy: 0.94
# <keras.engine.sequential.Sequential object at 0x7f3475e17820>
# <keras.engine.sequential.Sequential object at 0x7f3475e17820>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7f3475e17820>
# 1/1 [==============================] - 0s 21ms/step
# Confusion Matrix, without normalization
# [[5 0 1]
#  [0 6 0]
#  [0 0 6]]
# komponen
# FP : [0 0 1]    FN : [1 0 0]    TP : [5 6 6]    TN : [12 12 11]
# TPR
# [ 83.33333333 100.         100.        ]
# Precision
# [100.         100.          85.71428571]
# FDR
# [ 0.          0.         14.28571429]
# Akurasi
# [ 94.44444444 100.          94.44444444]
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9944
#
# accuracy: 99.44%
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 19)                513
#
#  dense_3 (Dense)             (None, 3)                 60
#
# =================================================================
# Total params: 573
# Trainable params: 573
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 7.8025 - accuracy: 0.4815 - 773ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 3.1000 - accuracy: 0.6358 - 217ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 1.4452 - accuracy: 0.7778 - 212ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.8371 - accuracy: 0.7963 - 206ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.4626 - accuracy: 0.9136 - 221ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.3417 - accuracy: 0.9074 - 230ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.2078 - accuracy: 0.9444 - 211ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.2106 - accuracy: 0.9321 - 225ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.1028 - accuracy: 0.9630 - 211ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.1105 - accuracy: 0.9630 - 208ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0699 - accuracy: 0.9753 - 239ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0395 - accuracy: 0.9753 - 277ms/epoch - 2ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0278 - accuracy: 0.9877 - 280ms/epoch - 2ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0252 - accuracy: 0.9877 - 292ms/epoch - 2ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0153 - accuracy: 0.9938 - 319ms/epoch - 2ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0168 - accuracy: 0.9938 - 277ms/epoch - 2ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0089 - accuracy: 1.0000 - 261ms/epoch - 2ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0082 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0087 - accuracy: 1.0000 - 278ms/epoch - 2ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0067 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0072 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0068 - accuracy: 1.0000 - 309ms/epoch - 2ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0051 - accuracy: 1.0000 - 285ms/epoch - 2ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0046 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0038 - accuracy: 1.0000 - 292ms/epoch - 2ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0038 - accuracy: 1.0000 - 288ms/epoch - 2ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0036 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0032 - accuracy: 1.0000 - 238ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0029 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0034 - accuracy: 1.0000 - 198ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 192ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 200ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 192ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 197ms/epoch - 1ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0017 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 9.8243e-04 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 9.3417e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 7.9396e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 7.3531e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 7.0604e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 5.8159e-04 - accuracy: 1.0000 - 248ms/epoch - 2ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 8.0004e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 5.5058e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 4.5381e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 4.0213e-04 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 4.2363e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 3.8492e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 2.9782e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 2.8602e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 2.6674e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 2.5722e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 2.6045e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 2.4613e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 1.9202e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 1.9906e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 1.8930e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 0.1185 - accuracy: 0.9753 - 218ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 0.0888 - accuracy: 0.9753 - 221ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 0.0027 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 3.6595e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 2.7262e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 2.4952e-04 - accuracy: 1.0000 - 200ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 2.2859e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 2.1084e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 1.9381e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 1.8054e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 1.7320e-04 - accuracy: 1.0000 - 268ms/epoch - 2ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 1.6353e-04 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 1.5302e-04 - accuracy: 1.0000 - 280ms/epoch - 2ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 1.4322e-04 - accuracy: 1.0000 - 277ms/epoch - 2ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 1.3584e-04 - accuracy: 1.0000 - 284ms/epoch - 2ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 1.2987e-04 - accuracy: 1.0000 - 285ms/epoch - 2ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 1.2512e-04 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.1990e-04 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.1761e-04 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.1345e-04 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.0529e-04 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.0185e-04 - accuracy: 1.0000 - 295ms/epoch - 2ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 9.4725e-05 - accuracy: 1.0000 - 303ms/epoch - 2ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 9.1702e-05 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 8.7179e-05 - accuracy: 1.0000 - 328ms/epoch - 2ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 8.0548e-05 - accuracy: 1.0000 - 303ms/epoch - 2ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 7.8400e-05 - accuracy: 1.0000 - 233ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 7.6176e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 7.2691e-05 - accuracy: 1.0000 - 193ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 6.8571e-05 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 6.6130e-05 - accuracy: 1.0000 - 194ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 6.2858e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 5.8814e-05 - accuracy: 1.0000 - 192ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 5.6336e-05 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 5.3560e-05 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 4.9639e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 4.7033e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9444
# Loss: 0.13, accuracy: 0.94
# <keras.engine.sequential.Sequential object at 0x7f345a18e110>
# <keras.engine.sequential.Sequential object at 0x7f345a18e110>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7f345a18e110>
# 1/1 [==============================] - 0s 25ms/step
# Confusion Matrix, without normalization
# [[6 0 0]
#  [0 6 0]
#  [1 0 5]]
# komponen
# FP : [1 0 0]    FN : [0 0 1]    TP : [6 6 5]    TN : [11 12 12]
# TPR
# [100.         100.          83.33333333]
# Precision
# [ 85.71428571 100.         100.        ]
# FDR
# [14.28571429  0.          0.        ]
# Akurasi
# [ 94.44444444 100.          94.44444444]
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9944
#
# accuracy: 99.44%
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 19)                513
#
#  dense_5 (Dense)             (None, 3)                 60
#
# =================================================================
# Total params: 573
# Trainable params: 573
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 3.6895 - accuracy: 0.5679 - 1s/epoch - 7ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.1650 - accuracy: 0.7778 - 219ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.6663 - accuracy: 0.8395 - 215ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.4173 - accuracy: 0.9074 - 222ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.2719 - accuracy: 0.9321 - 218ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.1562 - accuracy: 0.9506 - 213ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.0682 - accuracy: 0.9815 - 211ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0458 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0474 - accuracy: 0.9877 - 214ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0302 - accuracy: 0.9938 - 207ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0257 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0228 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0189 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0195 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0135 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0108 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0097 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0095 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0071 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0069 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0058 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0051 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0052 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0045 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0042 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0039 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0031 - accuracy: 1.0000 - 309ms/epoch - 2ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0030 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0027 - accuracy: 1.0000 - 303ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0025 - accuracy: 1.0000 - 332ms/epoch - 2ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0021 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 32/100
# 162/162 - 1s - loss: 0.0021 - accuracy: 1.0000 - 733ms/epoch - 5ms/step
# Epoch 33/100
# 162/162 - 1s - loss: 0.0022 - accuracy: 1.0000 - 911ms/epoch - 6ms/step
# Epoch 34/100
# 162/162 - 1s - loss: 0.0016 - accuracy: 1.0000 - 818ms/epoch - 5ms/step
# Epoch 35/100
# 162/162 - 1s - loss: 0.0016 - accuracy: 1.0000 - 653ms/epoch - 4ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 479ms/epoch - 3ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 470ms/epoch - 3ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 8.6577e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 8.8046e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 7.2098e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 6.2921e-04 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 5.9663e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 5.5022e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 7.1013e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 6.5741e-04 - accuracy: 1.0000 - 233ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 6.0211e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 3.7846e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 3.0587e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 3.0262e-04 - accuracy: 1.0000 - 241ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 2.7842e-04 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 2.7241e-04 - accuracy: 1.0000 - 261ms/epoch - 2ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 2.3178e-04 - accuracy: 1.0000 - 239ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 2.0857e-04 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.9253e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.7784e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 1.7942e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 1.7895e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 1.5407e-04 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 1.3462e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 1.1018e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 1.0260e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 8.9896e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 8.1471e-05 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 7.6142e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 6.3288e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 8.0334e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 6.0304e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 5.5225e-05 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 5.0132e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 4.4086e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 4.6686e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 4.1955e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 3.8802e-05 - accuracy: 1.0000 - 196ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 3.3925e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 3.6170e-05 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 2.9075e-05 - accuracy: 1.0000 - 275ms/epoch - 2ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 2.5805e-05 - accuracy: 1.0000 - 287ms/epoch - 2ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 2.3028e-05 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 2.2453e-05 - accuracy: 1.0000 - 306ms/epoch - 2ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.7807e-05 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.7222e-05 - accuracy: 1.0000 - 295ms/epoch - 2ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.6967e-05 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 1.5944e-05 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 1.3849e-05 - accuracy: 1.0000 - 313ms/epoch - 2ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 1.3294e-05 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 1.1298e-05 - accuracy: 1.0000 - 288ms/epoch - 2ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 1.0683e-05 - accuracy: 1.0000 - 311ms/epoch - 2ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 9.2370e-06 - accuracy: 1.0000 - 277ms/epoch - 2ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 8.7153e-06 - accuracy: 1.0000 - 315ms/epoch - 2ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 7.9559e-06 - accuracy: 1.0000 - 325ms/epoch - 2ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 7.1377e-06 - accuracy: 1.0000 - 315ms/epoch - 2ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 6.9456e-06 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 6.6020e-06 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 5.3099e-06 - accuracy: 1.0000 - 365ms/epoch - 2ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 6.0140e-06 - accuracy: 1.0000 - 309ms/epoch - 2ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 4.8853e-06 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 4.4629e-06 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Loss: 0.00, accuracy: 1.00
# <keras.engine.sequential.Sequential object at 0x7f3458702da0>
# <keras.engine.sequential.Sequential object at 0x7f3458702da0>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7f3458702da0>
# 1/1 [==============================] - 0s 91ms/step
# Confusion Matrix, without normalization
# [[6 0 0]
#  [0 6 0]
#  [0 0 6]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [6 6 6]    TN : [12 12 12]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# 6/6 [==============================] - 0s 3ms/step - loss: 3.8322e-04 - accuracy: 1.0000
#
# accuracy: 100.00%
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 19)                513
#
#  dense_7 (Dense)             (None, 3)                 60
#
# =================================================================
# Total params: 573
# Trainable params: 573
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 9.1976 - accuracy: 0.4321 - 771ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 2.2588 - accuracy: 0.6852 - 215ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 1.0672 - accuracy: 0.8025 - 225ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.6162 - accuracy: 0.8704 - 224ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.3382 - accuracy: 0.9321 - 210ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.3511 - accuracy: 0.8889 - 218ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.2224 - accuracy: 0.9136 - 223ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.1781 - accuracy: 0.9136 - 202ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0958 - accuracy: 0.9691 - 217ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.1013 - accuracy: 0.9444 - 218ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0724 - accuracy: 0.9691 - 211ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0977 - accuracy: 0.9691 - 217ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0423 - accuracy: 0.9938 - 221ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0585 - accuracy: 0.9691 - 206ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0302 - accuracy: 0.9877 - 209ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0370 - accuracy: 0.9877 - 224ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0430 - accuracy: 0.9815 - 211ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0327 - accuracy: 0.9877 - 219ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0152 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0106 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0095 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0127 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0077 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0071 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0078 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0086 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0066 - accuracy: 1.0000 - 235ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0049 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0054 - accuracy: 1.0000 - 317ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0037 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0040 - accuracy: 1.0000 - 303ms/epoch - 2ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0255 - accuracy: 0.9877 - 315ms/epoch - 2ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0097 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0031 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 0.0028 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0022 - accuracy: 1.0000 - 308ms/epoch - 2ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 311ms/epoch - 2ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 304ms/epoch - 2ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 321ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 319ms/epoch - 2ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 311ms/epoch - 2ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 0.1958 - accuracy: 0.9753 - 221ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 0.3217 - accuracy: 0.9259 - 218ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 0.0711 - accuracy: 0.9630 - 191ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 0.0192 - accuracy: 0.9938 - 203ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 0.0395 - accuracy: 0.9877 - 207ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 6.8982e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 6.3900e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 5.4626e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 5.2153e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 4.9065e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 4.6215e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 4.4493e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 4.2320e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 4.2158e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 4.1538e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 3.9552e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 3.9950e-04 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 3.6864e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 3.6499e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 3.5405e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 3.5088e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 3.4559e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 3.2926e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 3.5128e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 3.0700e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 3.1010e-04 - accuracy: 1.0000 - 243ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 3.0426e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 2.8341e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 2.7936e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 2.8496e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 2.7753e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 2.4888e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 2.6600e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 2.1345e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 2.3282e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 2.1328e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 2.2076e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 2.1212e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 2.1162e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.8617e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.6033e-04 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.6808e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.7333e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 1.4684e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 1.4675e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 1.3336e-04 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 1.3778e-04 - accuracy: 1.0000 - 271ms/epoch - 2ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 1.2530e-04 - accuracy: 1.0000 - 311ms/epoch - 2ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 1.1962e-04 - accuracy: 1.0000 - 292ms/epoch - 2ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 1.5477e-04 - accuracy: 1.0000 - 285ms/epoch - 2ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 1.3139e-04 - accuracy: 1.0000 - 292ms/epoch - 2ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 9.7700e-05 - accuracy: 1.0000 - 314ms/epoch - 2ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 8.2052e-05 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 7.8042e-05 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 1.0995e-04 - accuracy: 1.0000 - 313ms/epoch - 2ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 1.6121e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 8.8788e-05 - accuracy: 1.0000 - 265ms/epoch - 2ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 5.2361e-05 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Loss: 0.00, accuracy: 1.00
# <keras.engine.sequential.Sequential object at 0x7f34601946a0>
# <keras.engine.sequential.Sequential object at 0x7f34601946a0>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7f34601946a0>
# 1/1 [==============================] - 0s 22ms/step
# Confusion Matrix, without normalization
# [[6 0 0]
#  [0 6 0]
#  [0 0 6]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [6 6 6]    TN : [12 12 12]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7148e-04 - accuracy: 1.0000
#
# accuracy: 100.00%
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 19)                513
#
#  dense_9 (Dense)             (None, 3)                 60
#
# =================================================================
# Total params: 573
# Trainable params: 573
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 11.8679 - accuracy: 0.2593 - 752ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.6289 - accuracy: 0.6481 - 216ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.8543 - accuracy: 0.8148 - 224ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.5216 - accuracy: 0.8642 - 218ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.3771 - accuracy: 0.9136 - 229ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.2442 - accuracy: 0.9259 - 224ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.2416 - accuracy: 0.9383 - 216ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.1507 - accuracy: 0.9506 - 230ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.1072 - accuracy: 0.9630 - 241ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0911 - accuracy: 0.9506 - 233ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0629 - accuracy: 0.9815 - 230ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0657 - accuracy: 0.9753 - 232ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0525 - accuracy: 0.9815 - 227ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0518 - accuracy: 0.9938 - 241ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0323 - accuracy: 0.9877 - 221ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0299 - accuracy: 0.9877 - 223ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0139 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0168 - accuracy: 1.0000 - 249ms/epoch - 2ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0183 - accuracy: 0.9938 - 253ms/epoch - 2ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0190 - accuracy: 0.9938 - 227ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0096 - accuracy: 1.0000 - 232ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0080 - accuracy: 1.0000 - 243ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0080 - accuracy: 1.0000 - 234ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0079 - accuracy: 1.0000 - 310ms/epoch - 2ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0081 - accuracy: 1.0000 - 304ms/epoch - 2ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0071 - accuracy: 1.0000 - 292ms/epoch - 2ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0056 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0059 - accuracy: 1.0000 - 310ms/epoch - 2ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0051 - accuracy: 1.0000 - 309ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0046 - accuracy: 1.0000 - 318ms/epoch - 2ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0044 - accuracy: 1.0000 - 295ms/epoch - 2ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0046 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0036 - accuracy: 1.0000 - 312ms/epoch - 2ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0032 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 0.0029 - accuracy: 1.0000 - 317ms/epoch - 2ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0028 - accuracy: 1.0000 - 304ms/epoch - 2ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0028 - accuracy: 1.0000 - 296ms/epoch - 2ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 274ms/epoch - 2ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0020 - accuracy: 1.0000 - 292ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 238ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 197ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 198ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 8.8855e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 9.3437e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 6.9046e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 7.2753e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 5.7263e-04 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 5.0808e-04 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 5.0474e-04 - accuracy: 1.0000 - 231ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 4.9415e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 4.0763e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 4.0372e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 3.7706e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 3.2395e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 2.8777e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 2.9271e-04 - accuracy: 1.0000 - 232ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 2.9892e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 2.4764e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 2.0399e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 65/100
# ...
# Epoch 52/100
# 162/162 - 0s - loss: 7.8970e-04 - accuracy: 1.0000 - 233ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 7.0113e-04 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 6.8298e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 6.6423e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 5.8793e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 5.8337e-04 - accuracy: 1.0000 - 264ms/epoch - 2ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 5.8264e-04 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 4.9911e-04 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 5.2484e-04 - accuracy: 1.0000 - 314ms/epoch - 2ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 4.3454e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 4.4696e-04 - accuracy: 1.0000 - 322ms/epoch - 2ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 4.2065e-04 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 3.6255e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 3.6828e-04 - accuracy: 1.0000 - 310ms/epoch - 2ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 3.6086e-04 - accuracy: 1.0000 - 284ms/epoch - 2ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 3.0705e-04 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 2.9796e-04 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 2.7930e-04 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 2.6111e-04 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 2.6174e-04 - accuracy: 1.0000 - 331ms/epoch - 2ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 2.0389e-04 - accuracy: 1.0000 - 326ms/epoch - 2ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 2.2806e-04 - accuracy: 1.0000 - 252ms/epoch - 2ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 2.0234e-04 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 2.3727e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 1.8691e-04 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 1.7819e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 1.7045e-04 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 1.6523e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 2.2059e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.4086e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.3625e-04 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.2433e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.2606e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.0448e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 9.8666e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 8.6597e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 9.3066e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 7.9401e-05 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 7.1722e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 7.0548e-05 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 7.3595e-05 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 6.1283e-05 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 7.2506e-05 - accuracy: 1.0000 - 239ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 5.7249e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 5.2179e-05 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 4.2891e-05 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 4.1865e-05 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 3.7698e-05 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 3.2877e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2990 - accuracy: 0.9444
# Loss: 1.30, accuracy: 0.94
# <keras.engine.sequential.Sequential object at 0x7f34506a3a30>
# <keras.engine.sequential.Sequential object at 0x7f34506a3a30>
# 6/6 [==============================] - 0s 3ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7f34506a3a30>
# 1/1 [==============================] - 0s 21ms/step
# Confusion Matrix, without normalization
# [[5 1 0]
#  [0 6 0]
#  [0 0 6]]
# komponen
# FP : [0 1 0]    FN : [1 0 0]    TP : [5 6 6]    TN : [12 11 12]
# TPR
# [ 83.33333333 100.         100.        ]
# Precision
# [100.          85.71428571 100.        ]
# FDR
# [ 0.         14.28571429  0.        ]
# Akurasi
# [ 94.44444444  94.44444444 100.        ]
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9944
#
# accuracy: 99.44%
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 19)                513
#
#  dense_19 (Dense)            (None, 3)                 60
#
# =================================================================
# Total params: 573
# Trainable params: 573
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 8.2956 - accuracy: 0.4630 - 782ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.5527 - accuracy: 0.7654 - 227ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.8064 - accuracy: 0.8519 - 225ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.4737 - accuracy: 0.8889 - 236ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.2823 - accuracy: 0.9383 - 222ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.2532 - accuracy: 0.9321 - 212ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.1421 - accuracy: 0.9506 - 230ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0771 - accuracy: 0.9568 - 214ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0757 - accuracy: 0.9691 - 306ms/epoch - 2ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0441 - accuracy: 0.9877 - 320ms/epoch - 2ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0494 - accuracy: 0.9753 - 305ms/epoch - 2ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0140 - accuracy: 0.9938 - 290ms/epoch - 2ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0271 - accuracy: 0.9938 - 278ms/epoch - 2ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0191 - accuracy: 0.9938 - 286ms/epoch - 2ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0075 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0036 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0031 - accuracy: 1.0000 - 321ms/epoch - 2ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 276ms/epoch - 2ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0020 - accuracy: 1.0000 - 321ms/epoch - 2ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 313ms/epoch - 2ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 287ms/epoch - 2ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 328ms/epoch - 2ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 322ms/epoch - 2ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 9.5722e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.2193 - accuracy: 0.9691 - 227ms/epoch - 1ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.3967 - accuracy: 0.9074 - 214ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 0.1372 - accuracy: 0.9753 - 228ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0072 - accuracy: 0.9938 - 216ms/epoch - 1ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 0.0253 - accuracy: 0.9877 - 218ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 0.0402 - accuracy: 0.9877 - 220ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 0.0086 - accuracy: 0.9938 - 222ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 236ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 0.0058 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 2.7235e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 2.5530e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 2.4193e-04 - accuracy: 1.0000 - 230ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 2.3052e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 2.2507e-04 - accuracy: 1.0000 - 233ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 2.0977e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 1.9896e-04 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 1.9011e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 1.7934e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 1.7097e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 1.6162e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.5315e-04 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.4555e-04 - accuracy: 1.0000 - 230ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.4281e-04 - accuracy: 1.0000 - 236ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 1.3025e-04 - accuracy: 1.0000 - 243ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 1.3103e-04 - accuracy: 1.0000 - 238ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 1.2322e-04 - accuracy: 1.0000 - 234ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 1.1805e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 1.1322e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 1.0779e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 1.0237e-04 - accuracy: 1.0000 - 231ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 1.0080e-04 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 9.1133e-05 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 9.0467e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 8.5494e-05 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 8.1390e-05 - accuracy: 1.0000 - 321ms/epoch - 2ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 7.8381e-05 - accuracy: 1.0000 - 324ms/epoch - 2ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 7.6555e-05 - accuracy: 1.0000 - 319ms/epoch - 2ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 7.1743e-05 - accuracy: 1.0000 - 350ms/epoch - 2ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 6.8216e-05 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 6.5988e-05 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 6.1589e-05 - accuracy: 1.0000 - 345ms/epoch - 2ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 6.2092e-05 - accuracy: 1.0000 - 295ms/epoch - 2ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 5.7135e-05 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 5.5272e-05 - accuracy: 1.0000 - 276ms/epoch - 2ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 5.3781e-05 - accuracy: 1.0000 - 334ms/epoch - 2ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 4.8946e-05 - accuracy: 1.0000 - 320ms/epoch - 2ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 4.6572e-05 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 4.7416e-05 - accuracy: 1.0000 - 295ms/epoch - 2ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 4.6074e-05 - accuracy: 1.0000 - 275ms/epoch - 2ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 4.3060e-05 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 4.2653e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 3.8840e-05 - accuracy: 1.0000 - 234ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 3.9251e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 3.6853e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 3.4609e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 3.2105e-05 - accuracy: 1.0000 - 235ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 3.0804e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 3.0557e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 2.7148e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 2.7434e-05 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 2.6476e-05 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 2.5308e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 2.1982e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 2.0876e-05 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 2.1277e-05 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.8889
# Loss: 0.47, accuracy: 0.89
# <keras.engine.sequential.Sequential object at 0x7f345051e620>
# <keras.engine.sequential.Sequential object at 0x7f345051e620>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7f345051e620>
# 1/1 [==============================] - 0s 21ms/step
# Confusion Matrix, without normalization
# [[5 0 1]
#  [0 6 0]
#  [1 0 5]]
# komponen
# FP : [1 0 1]    FN : [1 0 1]    TP : [5 6 5]    TN : [11 12 11]
# TPR
# [ 83.33333333 100.          83.33333333]
# Precision
# [ 83.33333333 100.          83.33333333]
# FDR
# [16.66666667  0.         16.66666667]
# Akurasi
# [ 88.88888889 100.          88.88888889]
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9889
#
# accuracy: 98.89%
# akurasi tertinggi =  100.0
#
# Akurasi rata rata is 99.56%
