# %%
# !pip install pydub
# !pip install python_speech_features
# !pip install neuralnetwork
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python_speech_features
#   Building wheel for python_speech_features (setup.py) ... done
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5870 sha256=fd91d1c0c94927a19505d5169305531db601e3af9c9fec805b4f8f6a438682eb
#   Stored in directory: /root/.cache/pip/wheels/5a/9e/68/30bad9462b3926c29e315df16b562216d12bdc215f4d240294
# Successfully built python_speech_features
# Installing collected packages: python_speech_features
# Successfully installed python_speech_features-0.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting neuralnetwork
#   Downloading neuralnetwork-1.8-py3-none-any.whl (10 kB)
# Collecting python-dotenv (from neuralnetwork)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, neuralnetwork
# Successfully installed neuralnetwork-1.8 python-dotenv-1.0.0

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: fastai, imbalanced-learn, librosa, lightgbm, mlxtend, qudida, sklearn-pandas, yellowbrick

# %%
# !pip install scikit-learn==1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==1.0
#   Downloading scikit-learn-1.0.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 42.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (1.22.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0) (3.1.0)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (pyproject.toml) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-1.0-cp310-cp310-linux_x86_64.whl size=25849589 sha256=ecb40a88f4a35de02264dc559ff1be903394580849a739491bea91d35930a955
#   Stored in directory: /root/.cache/pip/wheels/dc/ac/81/f7dc596b727fdedc2b8f05ef115393b07478ee09a76edebdff
# Successfully built scikit-learn
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.10.1 requires scikit-learn>=1.0.2, but you have scikit-learn 1.0 which is incompatible.
# Successfully installed scikit-learn-1.0

# %% [markdown]
# IMPORT DATASET

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import matplotlib.pyplot as plt
import csv
import keras
import numpy
import random
import itertools
import tensorflow as tf
from numpy import *
from __future__ import division
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from numpy import loadtxt
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from timeit import default_timer as timer
from itertools import product
from sklearn.preprocessing import LabelEncoder

# %%
np.set_printoptions(suppress=True)

# mount gdrive with this code
from google.colab import drive
drive.mount('/content/drive')
#below where the file is in gdrive, change with your
feature_path = "/content/drive/My Drive/Program Skripsi/all_data/"
label_path = "/content/drive/My Drive/Program Skripsi/"

#load the dataset
#feature
feature = loadtxt(feature_path + 'feature_mfcc20_all_data.csv', delimiter=',')

#label
label = loadtxt(label_path + 'label_all_data.csv', delimiter=',')

X = feature
y = label

#print(X)
#print(y)

print(feature.shape)
# Out:
# Mounted at /content/drive
# (180, 40)

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion Matrix', cmap=plt.cm.Blues):
     """
     This function prints and plots the confusion matrix.
     Normalization can be applied by setting `normalize=True`.
     """
     if normalize:
       cm=cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
       print("Normalized Confusion Matrix")
     else:
       print('Confusion Matrix, without normalization')

     print(cm)
     plt.figure(figsize=(6,6), dpi=100)
     plt.imshow(cm, interpolation='nearest', cmap=cmap)
     plt.title(title)
     tick_marks = np.arange(len(classes))
     plt.xticks(tick_marks, classes, rotation=90)
     plt.yticks(tick_marks, classes)

     fmt = '.2f' if normalize else 'd'
     thresh = cm.max()/2
     for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
       plt.text(j, i, format(cm[i, j], fmt),
                horizontalalignment="center",
                color="white" if cm[i,j] > thresh else "black")

     plt.tight_layout()
     plt.ylabel('True Label')
     plt.xlabel('Predicted Label')

def tampil_cm_train(X_train, y_train, model):
    #confusion matrix
    class_names = ['Bali','Jawa','Madura']
    m = 1
    n = class_names
    m1 = str(m)
    m2 = str(n)
    model.save("feature_mfcc20_all_data_"+m2+'_'+m1+".hdf5") #sesuaikan dengan dataset yang digunakan
    print(model)

    pred_labels = model.predict(X_train)
    cm = confusion_matrix(y_train.argmax(axis=1), pred_labels.argmax(axis=1))
    cm

    class_names = ['Bali','Jawa','Madura']
    plot_confusion_matrix(cm, classes=class_names, normalize=False)
    plt.show()
    cm_stat(cm)
    return model.save("feature_mfcc20_all_data_"+m2+'_'+m1+".hdf5")

def tampil_cm_test(X_test, y_test, model):
    class_names = ['Bali','Jawa','Madura']
    m = 1
    n = class_names
    m1 = str(m)
    m2 = str(n)
    model.save("feature_mfcc20_all_data_"+m2+'_'+m1+".hdf5")
    print(model)

    pred_labels = model.predict(X_test) #test input
    cm = confusion_matrix(y_test.argmax(axis=1), pred_labels.argmax(axis=1))
    cm

    class_names = ['Bali','Jawa','Madura']
    plot_confusion_matrix(cm, classes=class_names, normalize=False)
    plt.show()
    cm_stat(cm)
    return model.save("feature_mfcc20_all_data_"+m2+'_'+m1+".hdf5")

def cm_stat(cm):
    FP = cm.sum(axis=0) - np.diag(cm)
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)
    print("komponen")
    print("FP :",FP,"   FN :",FN,"   TP :",TP,"   TN :",TN)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    print("TPR")
    print(TPR*100)
    # Specificity or true negative rate
    TNR = TN/(TN+FP)
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    print("Precision")
    print(PPV*100)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)
    print("FDR")
    print(FDR*100)

    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)
    print("Akurasi")
    print(ACC*100)

    return PPV,ACC,TPR,FDR

def predict(signal_predict):
    signals=np.stack([extract_feature_signal(signal_predict)])
    #do the prediction
    prediction = model.predict(signals, batch_size=1)
    print("Prediction: %s, confidence: %.2f" % (np.argmax(prediction), np.max(prediction)))

# %%
def labels_encoder(y):
    y_new = LabelEncoder().fit_transform([''.join(str(l)) for l in y])
    return y_new

def labels_decoder(y):
    lb = preprocessing.LabelBinarizer()
    lb.fit(y)
    lb.classes_
    labels_1_nn = lb.transform(y)
    return labels_1_nn

# %%
#TRAINING&TESTING
def trainingdata (X, y):
    seed = np.random.seed(25)
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed) #menyatakan fungsi KFoldnya
    kf.get_n_splits(X) #Memisah testing-training sesuai spesifikasi KFoldnya #feature itu nama datanya nanti diganti aja
    print(kf) #untuk melihat spesifikasi KFoldnya
    cvscores = []
    m = 1
    n = class_names
    for train, test in kf.split(X, y):
        y_new = labels_decoder(y)

        #define the keras model
        model = Sequential()
        model.add(Dense(29, input_dim=40, activation='relu')) #input layer = nodenya dihitung dari jumlah koefisien mfcc
        model.add(Dense(3, activation='softmax'))

        #compile the keras model
        model.compile(loss='categorical_crossentropy',
                      optimizer='adam',
                      metrics=['accuracy']) #menggunakan multiclass classification
        print(model.summary())

        X_train, X_test, y_train, y_test = X[train], X[test], y_new[train], y_new[test]

        #fit the keras model on the dataset
        model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2) #verbose digunakan agar tidak ada error saat training
        loss, acc = model.evaluate(X_test, y_test, batch_size=1)
        print("Loss: %.2f, accuracy: %.2f" %(loss, acc))

        m1 = str(m)
        m2 = str(n)

        model.save("feature_mfcc20_all_data_"+m2+'_'+m1+".hdf5") #tergantung jumlah koefisiennya
        print(model)

        tampil_cm_train(X_train, y_train, model)
        tampil_cm_test(X_test, y_test, model)

        m = m+1

        #evaluate the keras model
        scores = model.evaluate(X, y_new)
        print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
        cvscores.append(scores[1]*100)

    # print out average and standard deviation of model performance to provide a robust estimate of the model's accuracy.
    maks = max(cvscores)
    print("akurasi tertinggi = ", max(cvscores))
    print("\nAkurasi rata rata is %.2f%%" % numpy.mean(cvscores))
    return maks, numpy.mean(cvscores)

# %%
def run_all (X, y):
    X, y = feature, label
    max_acc, mean_acc = trainingdata(X, y)
    return max_acc, mean_acc

# %%
scores_logat = []
scores_logat_testing = []

class_names = ['Bali','Jawa','Madura']
logat_max_acc, logat_mean_acc = run_all (40,class_names)
scores_logat.append(logat_mean_acc)
# Out:
# StratifiedKFold(n_splits=10, random_state=None, shuffle=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 29)                1189
#
#  dense_1 (Dense)             (None, 3)                 90
#
# =================================================================
# Total params: 1,279
# Trainable params: 1,279
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 4.5233 - accuracy: 0.6111 - 937ms/epoch - 6ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.6359 - accuracy: 0.7407 - 212ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.7934 - accuracy: 0.8951 - 223ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.5183 - accuracy: 0.8704 - 210ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.2893 - accuracy: 0.9259 - 216ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.1700 - accuracy: 0.9444 - 220ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.1034 - accuracy: 0.9691 - 219ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0843 - accuracy: 0.9691 - 213ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0301 - accuracy: 0.9877 - 210ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0262 - accuracy: 0.9815 - 220ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0021 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 9.9729e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 8.9454e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 8.1137e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 7.5033e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 6.9664e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 6.3270e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 6.0129e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 5.3133e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 5.0615e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 4.6938e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 4.3716e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 4.0559e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 3.8898e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 3.7167e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 3.4406e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 3.3361e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 3.1008e-04 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 2.8677e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 2.6785e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 2.4513e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 2.3164e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 2.1543e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 2.0475e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 1.9981e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 1.8189e-04 - accuracy: 1.0000 - 234ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 1.6538e-04 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 1.6897e-04 - accuracy: 1.0000 - 280ms/epoch - 2ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 1.4535e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 1.3834e-04 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 1.2903e-04 - accuracy: 1.0000 - 281ms/epoch - 2ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 1.3067e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 1.1796e-04 - accuracy: 1.0000 - 279ms/epoch - 2ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 1.0962e-04 - accuracy: 1.0000 - 270ms/epoch - 2ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 1.0266e-04 - accuracy: 1.0000 - 255ms/epoch - 2ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 1.1818e-04 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 8.8396e-05 - accuracy: 1.0000 - 296ms/epoch - 2ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 8.1291e-05 - accuracy: 1.0000 - 283ms/epoch - 2ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 7.8059e-05 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 7.4376e-05 - accuracy: 1.0000 - 272ms/epoch - 2ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 6.8638e-05 - accuracy: 1.0000 - 278ms/epoch - 2ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 6.2161e-05 - accuracy: 1.0000 - 274ms/epoch - 2ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 6.1684e-05 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 5.7301e-05 - accuracy: 1.0000 - 195ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 5.1765e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 5.0305e-05 - accuracy: 1.0000 - 199ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 4.7964e-05 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 4.2086e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 3.9085e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 3.8898e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 3.3250e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 3.1580e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 3.0025e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 2.7946e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 2.7567e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 2.5512e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 2.1982e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 2.0876e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 2.0205e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 1.8047e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 1.6791e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 1.5947e-05 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 1.4682e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 1.3667e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 1.3108e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 1.1492e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 1.0820e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 1.0953e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.0931e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 8.4048e-06 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 8.7255e-06 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 8.2900e-06 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 7.0346e-06 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 6.4990e-06 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 5.9317e-06 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 5.3989e-06 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 5.5637e-06 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 4.7918e-06 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 4.5542e-06 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 4.4033e-06 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 4.1671e-06 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 5.0015e-06 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 3.8433e-06 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 3.2650e-06 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 2.9177e-06 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 2.4688e-06 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 2.2304e-06 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 2.1825e-06 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Loss: 0.01, accuracy: 1.00
# <keras.engine.sequential.Sequential object at 0x7fcb93ea2c80>
# <keras.engine.sequential.Sequential object at 0x7fcb93ea2c80>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7fcb93ea2c80>
# 1/1 [==============================] - 0s 22ms/step
# Confusion Matrix, without normalization
# [[6 0 0]
#  [0 6 0]
#  [0 0 6]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [6 6 6]    TN : [12 12 12]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# 6/6 [==============================] - 0s 3ms/step - loss: 5.1924e-04 - accuracy: 1.0000
#
# accuracy: 100.00%
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 29)                1189
#
#  dense_3 (Dense)             (None, 3)                 90
#
# =================================================================
# Total params: 1,279
# Trainable params: 1,279
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 8.4175 - accuracy: 0.4753 - 740ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 2.4450 - accuracy: 0.7222 - 203ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 1.0159 - accuracy: 0.8210 - 214ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.5517 - accuracy: 0.8889 - 205ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.3600 - accuracy: 0.9136 - 206ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.1163 - accuracy: 0.9444 - 219ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.0517 - accuracy: 0.9753 - 213ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0791 - accuracy: 0.9691 - 207ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0084 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0051 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0036 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0029 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0025 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0033 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0024 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0022 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0017 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 9.8735e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 9.2298e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 8.9110e-04 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 8.7404e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 7.7122e-04 - accuracy: 1.0000 - 295ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 7.0097e-04 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 7.3657e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 6.1015e-04 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 5.4505e-04 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 5.7763e-04 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 5.0464e-04 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 4.9591e-04 - accuracy: 1.0000 - 304ms/epoch - 2ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 4.3649e-04 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 4.2243e-04 - accuracy: 1.0000 - 258ms/epoch - 2ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 3.5222e-04 - accuracy: 1.0000 - 296ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 3.8732e-04 - accuracy: 1.0000 - 296ms/epoch - 2ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 3.7216e-04 - accuracy: 1.0000 - 308ms/epoch - 2ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 3.3269e-04 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 2.8080e-04 - accuracy: 1.0000 - 311ms/epoch - 2ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 2.5416e-04 - accuracy: 1.0000 - 305ms/epoch - 2ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 2.8818e-04 - accuracy: 1.0000 - 235ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 2.5891e-04 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 2.0741e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 1.9465e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 1.8955e-04 - accuracy: 1.0000 - 194ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 1.8211e-04 - accuracy: 1.0000 - 197ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 1.5142e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 1.4311e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 1.4525e-04 - accuracy: 1.0000 - 198ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 1.2966e-04 - accuracy: 1.0000 - 192ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 1.1514e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.1183e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.1186e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.0047e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 7.8833e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 7.7182e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 7.5243e-05 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 6.2695e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 5.7290e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 5.5266e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 5.6835e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 4.7501e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 4.2468e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 3.7214e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 3.9586e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 3.7230e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 2.8739e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 2.9857e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 2.5644e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 2.5213e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 2.3898e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 1.9243e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 1.7832e-05 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 1.8498e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 1.6029e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 1.4499e-05 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.3204e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.4283e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.1953e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.0921e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 9.6807e-06 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 8.9861e-06 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 8.4916e-06 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 7.9088e-06 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 7.1539e-06 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 6.4806e-06 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 6.8860e-06 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 5.2996e-06 - accuracy: 1.0000 - 267ms/epoch - 2ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 5.0884e-06 - accuracy: 1.0000 - 278ms/epoch - 2ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 4.9736e-06 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 4.2429e-06 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 3.7712e-06 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 4.1127e-06 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 3.1465e-06 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 3.3179e-06 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 3.3577e-06 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# 18/18 [==============================] - 0s 3ms/step - loss: 1.3108 - accuracy: 0.8889
# Loss: 1.31, accuracy: 0.89
# <keras.engine.sequential.Sequential object at 0x7fcaf9f07e50>
# <keras.engine.sequential.Sequential object at 0x7fcaf9f07e50>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7fcaf9f07e50>
# 1/1 [==============================] - 0s 33ms/step
# Confusion Matrix, without normalization
# [[5 1 0]
#  [0 6 0]
#  [1 0 5]]
# komponen
# FP : [1 1 0]    FN : [1 0 1]    TP : [5 6 5]    TN : [11 11 12]
# TPR
# [ 83.33333333 100.          83.33333333]
# Precision
# [ 83.33333333  85.71428571 100.        ]
# FDR
# [16.66666667 14.28571429  0.        ]
# Akurasi
# [88.88888889 94.44444444 94.44444444]
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1311 - accuracy: 0.9889
#
# accuracy: 98.89%
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 29)                1189
#
#  dense_5 (Dense)             (None, 3)                 90
#
# =================================================================
# Total params: 1,279
# Trainable params: 1,279
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 6.2695 - accuracy: 0.5864 - 778ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 2.3905 - accuracy: 0.7716 - 212ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 1.1260 - accuracy: 0.8025 - 222ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.6267 - accuracy: 0.8889 - 207ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.3042 - accuracy: 0.9259 - 209ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.3133 - accuracy: 0.9321 - 205ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.1579 - accuracy: 0.9383 - 215ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.1001 - accuracy: 0.9753 - 216ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0436 - accuracy: 0.9815 - 204ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0553 - accuracy: 0.9815 - 216ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0169 - accuracy: 0.9938 - 209ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0229 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0054 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0040 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0042 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0039 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0038 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0028 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0024 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0024 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0023 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0022 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 8.5731e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 8.7630e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 7.5712e-04 - accuracy: 1.0000 - 235ms/epoch - 1ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 8.1001e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 6.3126e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 8.4694e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 6.0217e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 4.7034e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 4.8010e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 4.3743e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 4.6569e-04 - accuracy: 1.0000 - 278ms/epoch - 2ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 3.6946e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 3.3140e-04 - accuracy: 1.0000 - 287ms/epoch - 2ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 3.5783e-04 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 3.2840e-04 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 2.6781e-04 - accuracy: 1.0000 - 268ms/epoch - 2ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 2.3303e-04 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 2.3280e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 2.0646e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 1.9631e-04 - accuracy: 1.0000 - 287ms/epoch - 2ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 1.8547e-04 - accuracy: 1.0000 - 267ms/epoch - 2ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 1.5916e-04 - accuracy: 1.0000 - 306ms/epoch - 2ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.3984e-04 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.5047e-04 - accuracy: 1.0000 - 284ms/epoch - 2ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.3670e-04 - accuracy: 1.0000 - 298ms/epoch - 2ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 1.2385e-04 - accuracy: 1.0000 - 310ms/epoch - 2ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 1.1323e-04 - accuracy: 1.0000 - 280ms/epoch - 2ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 1.0937e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 9.3436e-05 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 2.0435e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 2.1646e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 8.0889e-05 - accuracy: 1.0000 - 197ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 5.7684e-05 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 5.8280e-05 - accuracy: 1.0000 - 202ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 4.7359e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 4.6279e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 4.2010e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 3.9778e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 3.7822e-05 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 3.6846e-05 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 3.0505e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 2.7375e-05 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 2.5975e-05 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 2.2949e-05 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 2.3510e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 2.0695e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 1.9053e-05 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.9207e-05 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.7066e-05 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.5350e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.4538e-05 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.3452e-05 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 1.2596e-05 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 1.1269e-05 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 9.9073e-06 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 9.9758e-06 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 8.3878e-06 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 7.6476e-06 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 7.3150e-06 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 7.0737e-06 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 6.0936e-06 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 5.3673e-06 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 5.1200e-06 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 5.1487e-06 - accuracy: 1.0000 - 201ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 6.5313e-06 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 3.9368e-06 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 3.8537e-06 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.8889
# Loss: 0.20, accuracy: 0.89
# <keras.engine.sequential.Sequential object at 0x7fcaf9d3f280>
# <keras.engine.sequential.Sequential object at 0x7fcaf9d3f280>
# 6/6 [==============================] - 0s 2ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7fcaf9d3f280>
# 1/1 [==============================] - 0s 23ms/step
# Confusion Matrix, without normalization
# [[5 0 1]
#  [0 6 0]
#  [1 0 5]]
# komponen
# FP : [1 0 1]    FN : [1 0 1]    TP : [5 6 5]    TN : [11 12 11]
# TPR
# [ 83.33333333 100.          83.33333333]
# Precision
# [ 83.33333333 100.          83.33333333]
# FDR
# [16.66666667  0.         16.66666667]
# Akurasi
# [ 88.88888889 100.          88.88888889]
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9889
#
# accuracy: 98.89%
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 29)                1189
#
#  dense_7 (Dense)             (None, 3)                 90
#
# =================================================================
# Total params: 1,279
# Trainable params: 1,279
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 6.3803 - accuracy: 0.3580 - 740ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 2.3098 - accuracy: 0.6111 - 216ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 1.1653 - accuracy: 0.7778 - 299ms/epoch - 2ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.6933 - accuracy: 0.8395 - 293ms/epoch - 2ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.4684 - accuracy: 0.8519 - 286ms/epoch - 2ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.2839 - accuracy: 0.8951 - 277ms/epoch - 2ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.1528 - accuracy: 0.9321 - 295ms/epoch - 2ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.1113 - accuracy: 0.9444 - 266ms/epoch - 2ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0941 - accuracy: 0.9630 - 290ms/epoch - 2ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0775 - accuracy: 0.9753 - 279ms/epoch - 2ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0308 - accuracy: 0.9938 - 301ms/epoch - 2ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0233 - accuracy: 1.0000 - 302ms/epoch - 2ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0249 - accuracy: 0.9938 - 273ms/epoch - 2ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0178 - accuracy: 1.0000 - 310ms/epoch - 2ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0118 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0089 - accuracy: 1.0000 - 313ms/epoch - 2ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0072 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0068 - accuracy: 1.0000 - 296ms/epoch - 2ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0054 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0050 - accuracy: 1.0000 - 247ms/epoch - 2ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0045 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0039 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0046 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0034 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0032 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0028 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0024 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0020 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 274ms/epoch - 2ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 315ms/epoch - 2ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 278ms/epoch - 2ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 9.6382e-04 - accuracy: 1.0000 - 277ms/epoch - 2ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 8.9225e-04 - accuracy: 1.0000 - 314ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 8.3054e-04 - accuracy: 1.0000 - 303ms/epoch - 2ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 7.0529e-04 - accuracy: 1.0000 - 293ms/epoch - 2ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 6.5274e-04 - accuracy: 1.0000 - 281ms/epoch - 2ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 6.5373e-04 - accuracy: 1.0000 - 267ms/epoch - 2ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 5.5226e-04 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 5.4703e-04 - accuracy: 1.0000 - 280ms/epoch - 2ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 4.5943e-04 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 4.0977e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 3.6784e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 3.4119e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 3.1085e-04 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 3.1017e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 2.6567e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 2.6034e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 2.3437e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 2.0594e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.8442e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.7023e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.5539e-04 - accuracy: 1.0000 - 238ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 1.4669e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 1.4225e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 1.3311e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 1.1031e-04 - accuracy: 1.0000 - 229ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 1.0093e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 9.8822e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 8.6647e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 7.9526e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 6.9959e-05 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 6.4495e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 6.6909e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 5.5081e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 5.0740e-05 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 4.7131e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 4.7067e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 3.8988e-05 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 3.7133e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 3.2630e-05 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 3.2551e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 2.8003e-05 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 2.8095e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 2.3389e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 2.0650e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.9025e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.8493e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.7108e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.5813e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 1.4741e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 1.2940e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 1.1365e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 1.1085e-05 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 9.8882e-06 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 9.4055e-06 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 8.1745e-06 - accuracy: 1.0000 - 277ms/epoch - 2ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 7.9626e-06 - accuracy: 1.0000 - 297ms/epoch - 2ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 7.0428e-06 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 6.5277e-06 - accuracy: 1.0000 - 299ms/epoch - 2ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 5.7139e-06 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 5.5498e-06 - accuracy: 1.0000 - 303ms/epoch - 2ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 4.9971e-06 - accuracy: 1.0000 - 305ms/epoch - 2ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 4.4460e-06 - accuracy: 1.0000 - 279ms/epoch - 2ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 4.1524e-06 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 1.9624 - accuracy: 0.9444
# Loss: 1.96, accuracy: 0.94
# <keras.engine.sequential.Sequential object at 0x7fcb0daa3c40>
# <keras.engine.sequential.Sequential object at 0x7fcb0daa3c40>
# 6/6 [==============================] - 0s 3ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7fcb0daa3c40>
# 1/1 [==============================] - 0s 22ms/step
# Confusion Matrix, without normalization
# [[5 0 1]
#  [0 6 0]
#  [0 0 6]]
# komponen
# FP : [0 0 1]    FN : [1 0 0]    TP : [5 6 6]    TN : [12 12 11]
# TPR
# [ 83.33333333 100.         100.        ]
# Precision
# [100.         100.          85.71428571]
# FDR
# [ 0.          0.         14.28571429]
# Akurasi
# [ 94.44444444 100.          94.44444444]
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1962 - accuracy: 0.9944
#
# accuracy: 99.44%
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 29)                1189
#
#  dense_9 (Dense)             (None, 3)                 90
#
# =================================================================
# Total params: 1,279
# Trainable params: 1,279
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 5.9944 - accuracy: 0.5494 - 742ms/epoch - 5ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.8964 - accuracy: 0.7222 - 212ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.9224 - accuracy: 0.8210 - 218ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.4685 - accuracy: 0.8765 - 219ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.2735 - accuracy: 0.9012 - 208ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.1512 - accuracy: 0.9383 - 219ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.0820 - accuracy: 0.9630 - 213ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0614 - accuracy: 0.9815 - 214ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0582 - accuracy: 0.9753 - 220ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0338 - accuracy: 0.9877 - 215ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0209 - accuracy: 0.9938 - 218ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0374 - accuracy: 0.9938 - 213ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0147 - accuracy: 0.9938 - 218ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0043 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0037 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0025 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0022 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0022 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0019 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0018 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0013 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 225ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 9.6098e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 9.1591e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 8.5376e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 8.2162e-04 - accuracy: 1.0000 - 269ms/epoch - 2ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 7.4265e-04 - accuracy: 1.0000 - 280ms/epoch - 2ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 6.9290e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 5.8409e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 7.5050e-04 - accuracy: 1.0000 - 312ms/epoch - 2ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 6.9012e-04 - accuracy: 1.0000 - 291ms/epoch - 2ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 6.5865e-04 - accuracy: 1.0000 - 273ms/epoch - 2ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 4.3556e-04 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 5.0004e-04 - accuracy: 1.0000 - 261ms/epoch - 2ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 3.8754e-04 - accuracy: 1.0000 - 252ms/epoch - 2ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 3.6101e-04 - accuracy: 1.0000 - 276ms/epoch - 2ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 2.9292e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 3.1283e-04 - accuracy: 1.0000 - 307ms/epoch - 2ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 2.8491e-04 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 2.6806e-04 - accuracy: 1.0000 - 289ms/epoch - 2ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 2.4380e-04 - accuracy: 1.0000 - 292ms/epoch - 2ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 2.2109e-04 - accuracy: 1.0000 - 282ms/epoch - 2ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 2.1508e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 1.7468e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 1.7738e-04 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 1.7584e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 1.9910e-04 - accuracy: 1.0000 - 206ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 1.6649e-04 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 1.3639e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.3842e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.1444e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.0669e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 9.6711e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# ...
# Epoch 52/100
# 162/162 - 0s - loss: 2.1452e-04 - accuracy: 1.0000 - 204ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 1.6604e-04 - accuracy: 1.0000 - 207ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 2.1803e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 1.8019e-04 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.7762e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.6579e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.6264e-04 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 1.4074e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 1.5243e-04 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 1.3512e-04 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 8.6136e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 1.1109e-04 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 7.0667e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 5.5026e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 7.2201e-05 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 5.0045e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 4.3315e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 4.2823e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 5.2405e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 4.5054e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 3.6423e-05 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 3.0750e-05 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 2.9849e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 0.8544 - accuracy: 0.9012 - 221ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 0.2545 - accuracy: 0.9383 - 211ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 0.0063 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 3.3203e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 2.4983e-04 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 2.0586e-04 - accuracy: 1.0000 - 242ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.8268e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.6531e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.5162e-04 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.4203e-04 - accuracy: 1.0000 - 232ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.3326e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 1.2503e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 1.1890e-04 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 1.1300e-04 - accuracy: 1.0000 - 210ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 1.0765e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 1.0323e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 9.9505e-05 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 9.5113e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 9.0643e-05 - accuracy: 1.0000 - 230ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 8.7402e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 8.4404e-05 - accuracy: 1.0000 - 277ms/epoch - 2ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 8.1376e-05 - accuracy: 1.0000 - 319ms/epoch - 2ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 7.8133e-05 - accuracy: 1.0000 - 332ms/epoch - 2ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 7.5126e-05 - accuracy: 1.0000 - 314ms/epoch - 2ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 7.1907e-05 - accuracy: 1.0000 - 306ms/epoch - 2ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 6.9068e-05 - accuracy: 1.0000 - 294ms/epoch - 2ms/step
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2380 - accuracy: 0.9444
# Loss: 0.24, accuracy: 0.94
# <keras.engine.sequential.Sequential object at 0x7fcaf97a55d0>
# <keras.engine.sequential.Sequential object at 0x7fcaf97a55d0>
# 6/6 [==============================] - 0s 3ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7fcaf97a55d0>
# 1/1 [==============================] - 0s 51ms/step
# Confusion Matrix, without normalization
# [[6 0 0]
#  [0 6 0]
#  [1 0 5]]
# komponen
# FP : [1 0 0]    FN : [0 0 1]    TP : [6 6 5]    TN : [11 12 12]
# TPR
# [100.         100.          83.33333333]
# Precision
# [ 85.71428571 100.         100.        ]
# FDR
# [14.28571429  0.          0.        ]
# Akurasi
# [ 94.44444444 100.          94.44444444]
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9944
#
# accuracy: 99.44%
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 29)                1189
#
#  dense_19 (Dense)            (None, 3)                 90
#
# =================================================================
# Total params: 1,279
# Trainable params: 1,279
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 162/162 - 1s - loss: 4.3051 - accuracy: 0.5864 - 1s/epoch - 7ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 1.0676 - accuracy: 0.7593 - 231ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.4255 - accuracy: 0.8827 - 217ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.2227 - accuracy: 0.8951 - 212ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.1308 - accuracy: 0.9630 - 217ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.1302 - accuracy: 0.9506 - 224ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.1453 - accuracy: 0.9321 - 223ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0226 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0227 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0180 - accuracy: 1.0000 - 230ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0095 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0078 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0064 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0053 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0043 - accuracy: 1.0000 - 228ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0049 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0042 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0039 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0030 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0027 - accuracy: 1.0000 - 227ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0028 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0026 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0025 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0024 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0017 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0016 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0014 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0015 - accuracy: 1.0000 - 231ms/epoch - 1ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0012 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0011 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0010 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 9.4545e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 8.4387e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 7.8430e-04 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 7.7641e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 6.2495e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 6.1171e-04 - accuracy: 1.0000 - 222ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 5.8234e-04 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 5.4648e-04 - accuracy: 1.0000 - 211ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 4.4165e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 4.1502e-04 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 4.0205e-04 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 3.5298e-04 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 3.3314e-04 - accuracy: 1.0000 - 212ms/epoch - 1ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 2.9029e-04 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 2.7669e-04 - accuracy: 1.0000 - 296ms/epoch - 2ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 2.5983e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 2.2654e-04 - accuracy: 1.0000 - 321ms/epoch - 2ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 2.0394e-04 - accuracy: 1.0000 - 326ms/epoch - 2ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 2.2049e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 1.6533e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 1.7382e-04 - accuracy: 1.0000 - 286ms/epoch - 2ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 1.4398e-04 - accuracy: 1.0000 - 300ms/epoch - 2ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 1.5238e-04 - accuracy: 1.0000 - 301ms/epoch - 2ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 1.3314e-04 - accuracy: 1.0000 - 308ms/epoch - 2ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 1.1048e-04 - accuracy: 1.0000 - 285ms/epoch - 2ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 1.0691e-04 - accuracy: 1.0000 - 311ms/epoch - 2ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 1.1072e-04 - accuracy: 1.0000 - 310ms/epoch - 2ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 9.5030e-05 - accuracy: 1.0000 - 290ms/epoch - 2ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 8.1508e-05 - accuracy: 1.0000 - 323ms/epoch - 2ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 7.4522e-05 - accuracy: 1.0000 - 316ms/epoch - 2ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 7.1146e-05 - accuracy: 1.0000 - 256ms/epoch - 2ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 7.5094e-05 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 5.6455e-05 - accuracy: 1.0000 - 205ms/epoch - 1ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 5.3027e-05 - accuracy: 1.0000 - 208ms/epoch - 1ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 4.6198e-05 - accuracy: 1.0000 - 203ms/epoch - 1ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 4.2736e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 4.0635e-05 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 3.6090e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 3.2899e-05 - accuracy: 1.0000 - 209ms/epoch - 1ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 3.1599e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 2.8594e-05 - accuracy: 1.0000 - 213ms/epoch - 1ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 2.6593e-05 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 2.4995e-05 - accuracy: 1.0000 - 230ms/epoch - 1ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 2.1581e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 2.1827e-05 - accuracy: 1.0000 - 221ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 1.8056e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 1.8591e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 1.5479e-05 - accuracy: 1.0000 - 219ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 1.4864e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 1.4486e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 1.1850e-05 - accuracy: 1.0000 - 230ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 1.0272e-05 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 1.0310e-05 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 1.0094e-05 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 8.5034e-06 - accuracy: 1.0000 - 223ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 8.0670e-06 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 7.0060e-06 - accuracy: 1.0000 - 217ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 6.3084e-06 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 5.7970e-06 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 5.2503e-06 - accuracy: 1.0000 - 224ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 5.6954e-06 - accuracy: 1.0000 - 215ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 4.8036e-06 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 4.5402e-06 - accuracy: 1.0000 - 218ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 4.1318e-06 - accuracy: 1.0000 - 220ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 3.4563e-06 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 3.3790e-06 - accuracy: 1.0000 - 216ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 2.8301e-06 - accuracy: 1.0000 - 226ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 3.0817e-06 - accuracy: 1.0000 - 214ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8471 - accuracy: 0.8889
# Loss: 0.85, accuracy: 0.89
# <keras.engine.sequential.Sequential object at 0x7fcaf959be80>
# <keras.engine.sequential.Sequential object at 0x7fcaf959be80>
# 6/6 [==============================] - 0s 4ms/step
# Confusion Matrix, without normalization
# [[54  0  0]
#  [ 0 54  0]
#  [ 0  0 54]]
# komponen
# FP : [0 0 0]    FN : [0 0 0]    TP : [54 54 54]    TN : [108 108 108]
# TPR
# [100. 100. 100.]
# Precision
# [100. 100. 100.]
# FDR
# [0. 0. 0.]
# Akurasi
# [100. 100. 100.]
# <keras.engine.sequential.Sequential object at 0x7fcaf959be80>
# 1/1 [==============================] - 0s 21ms/step
# Confusion Matrix, without normalization
# [[6 0 0]
#  [0 6 0]
#  [2 0 4]]
# komponen
# FP : [2 0 0]    FN : [0 0 2]    TP : [6 6 4]    TN : [10 12 12]
# TPR
# [100.         100.          66.66666667]
# Precision
# [ 75. 100. 100.]
# FDR
# [25.  0.  0.]
# Akurasi
# [ 88.88888889 100.          88.88888889]
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.9889
#
# accuracy: 98.89%
# akurasi tertinggi =  100.0
#
# Akurasi rata rata is 99.28%
